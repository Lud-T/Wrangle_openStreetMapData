# %% [markdown]
# # References
#
# ## UDACITY
#
# 4. Data Wrangling With MongoDB
#
# LESSON 5 DATA QUALITY
#
# 8. Example Using our Blueprint
#
# https://classroom.udacity.com/nanodegrees/nd002-airbus/parts/35305c70-58f5-4614-b7d6-302fa3f916a3/modules/2166796a-7560-4387-ac5e-c6a4b8d2d61c/lessons/699689362/concepts/7796785460923
#
#
#
# LESSON 13 CASE STUDY
#
# 3. Iterative Parsing
#
# https://classroom.udacity.com/nanodegrees/nd002-airbus/parts/35305c70-58f5-4614-b7d6-302fa3f916a3/modules/2166796a-7560-4387-ac5e-c6a4b8d2d61c/lessons/5436095827/concepts/54475500150923
#
#
#
# ## NOTA
#
# As a python beginner, I put details I discovered learning on the documentation, tutorials, projects and trials in order to refer to my own work afterwards.

# %% [markdown]
# ### First  tags analysis
#
# Although we have a description of the data into the OSM wiki.
#
# To understand parsing and the data, I feel the need to analyse the different level of tags.

# %%
#
#Basic code I'll use to go trhu the XML and count.
#
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.ElementTree as ET
import re
from pprint import pprint
import operator

#osm_file = 'data/small_sample_map.osm'
osm_file = 'data/map.osm'

def count_tags(filename):
    #count is a dictionary, dictionary manage pairs
    count = {}
    #Loop all the element in the file at first level !
    #All element are tags
    for _, element in ET.iterparse(filename):
        tag = element.tag
        #print(tag)
        #tag variable <= tag name
        #If tag name is not present in the count dict
        #add tag name in the dict with value 1
        if tag not in count.keys():
            count[tag] = 1
        #If tag name is already existing in the count dict
        #add 1  to the value of the already existing tag name
        else:
            count[tag] += 1

    return count



def main():
    #call function and return a dictionary
    count = count_tags(osm_file)
    #Sort dictionary
    count = sorted(count.items(), key=operator.itemgetter(1))[::1]
    #Display dictionary !
    pprint(count)

    
if __name__ == "__main__":
    main()
# Out:
# [('note', 1),
#  ('meta', 1),
#  ('bounds', 1),
#  ('osm', 1),
#  ('relation', 400),
#  ('way', 58953),
#  ('member', 124844),
#  ('tag', 156258),
#  ('node', 352867),
#  ('nd', 482449)]

# %% [markdown]
# **The tags are the same as described in OSM wiki datamodel**

# %% [markdown]
# ### Keys analysis
#
# Now, I check the keys and count them.
#
# My goal will be to look for relevant keys and check if it is easy to find errors.

# %%
#
#Basic code I'll use to go trhu the XML and count.
#
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.ElementTree as ET
import re
from pprint import pprint
import operator

#osm_file = 'data/small_sample_map.osm'
osm_file = 'data/map.osm'

def count_tags(filename):
    #count is a dictionary, dictionary manage pairs
    count = {}
    #Loop all the element in the file at first level !
    #All element are tags
    for _, element in ET.iterparse(filename):
        #print(element.tag)
        tagK = element.get('k')
        #tagK variable <= Key name
        #If there is a k value count it
        if tagK:
            #If Key name is not present in the count dict
            #add Key name in the dict with value 1
            if tagK not in count.keys():
                count[tagK] = 1
            #If Key name  is already existing in the count dict
            #add 1  to the value of the already existing Key name 
            else:
                count[tagK] += 1

    return count



def main():
    #call function and return a dictionary
    count = count_tags(osm_file)
    #Sort dictionary
    count = sorted(count.items(), key=operator.itemgetter(1))[::-1]
    #Display dictionary !
    pprint(count)

    
if __name__ == "__main__":
    main()
# Out:
# [('source', 53853),
#  ('building', 47328),
#  ('wall', 16350),
#  ('highway', 6638),
#  ('leisure', 3671),
#  ('access', 3575),
#  ('name', 3402),
#  ('operator', 1371),
#  ('ref', 1199),
#  ('power', 1196),
#  ('oneway', 1110),
#  ('natural', 919),
#  ('amenity', 880),
#  ('addr:housenumber', 852),
#  ('landuse', 671),
#  ('barrier', 558),
#  ('surface', 451),
#  ('type', 400),
#  ('maxspeed', 390),
#  ('service', 338),
#  ('waterway', 301),
#  ('layer', 282),
#  ('network', 244),
#  ('motor_vehicle', 240),
#  ('ref:FR:FANTOIR', 227),
#  ('addr:street', 207),
#  ('shop', 181),
#  ('sport', 163),
#  ('foot', 158),
#  ('description', 154),
#  ('cycleway', 146),
#  ('bicycle', 142),
#  ('bridge', 140),
#  ('addr:city', 137),
#  ('addr:postcode', 136),
#  ('name:oc', 131),
#  ('lanes', 129),
#  ('tunnel', 127),
#  ('route', 124),
#  ('crossing', 123),
#  ('source:name:oc', 122),
#  ('junction', 120),
#  ('note', 119),
#  ('man_made', 117),
#  ('public_transport', 114),
#  ('golf', 113),
#  ('url', 109),
#  ('tracktype', 103),
#  ('crossing_ref', 101),
#  ('bus', 100),
#  ('to', 98),
#  ('from', 98),
#  ('place', 98),
#  ('voltage', 95),
#  ('capacity', 94),
#  ('wikidata', 92),
#  ('parking', 92),
#  ('brand', 92),
#  ('CLC:id', 91),
#  ('CLC:code', 91),
#  ('CLC:year', 90),
#  ('toll', 90),
#  ('website', 88),
#  ('int_ref', 86),
#  ('public_transport:version', 85),
#  ('brand:wikidata', 84),
#  ('emergency', 81),
#  ('old_ref', 77),
#  ('boundary', 74),
#  ('traffic_calming', 73),
#  ('smoothness', 71),
#  ('wikipedia', 71),
#  ('opening_hours', 71),
#  ('phone', 69),
#  ('tourism', 69),
#  ('brand:wikipedia', 68),
#  ('zone:maxspeed', 64),
#  ('bench', 63),
#  ('ele', 63),
#  ('shelter', 62),
#  ('name:fr', 61),
#  ('historic', 61),
#  ('created_by', 59),
#  ('aeroway', 58),
#  ('fee', 58),
#  ('name:de', 57),
#  ('backrest', 57),
#  ('usage', 55),
#  ('colour', 55),
#  ('wheelchair', 51),
#  ('mtb:scale', 48),
#  ('covered', 47),
#  ('recycling_type', 47),
#  ('area', 46),
#  ('frequency', 46),
#  ('railway', 43),
#  ('height', 43),
#  ('source:maxspeed', 41),
#  ('school:FR', 41),
#  ('site', 38),
#  ('admin_level', 38),
#  ('building:levels', 37),
#  ('tactile_paving', 36),
#  ('footway', 35),
#  ('material', 35),
#  ('leaf_type', 35),
#  ('recycling:paper', 35),
#  ('fixme', 35),
#  ('ref:UAI', 34),
#  ('cycleway:right', 33),
#  ('horse', 33),
#  ('cables', 32),
#  ('route_master', 31),
#  ('hgv', 30),
#  ('start_date', 30),
#  ('contact:phone', 30),
#  ('importance', 28),
#  ('width', 28),
#  ('location', 28),
#  ('ref:FR:FINESS', 28),
#  ('gauge', 27),
#  ('cuisine', 27),
#  ('railway:traffic_mode', 26),
#  ('railway:track_ref', 26),
#  ('railway:radio', 26),
#  ('railway:preferred_direction', 26),
#  ('railway:bidirectional', 26),
#  ('passenger_lines', 26),
#  ('electrified', 26),
#  ('recycling:cans', 26),
#  ('highspeed', 25),
#  ('cycleway:left', 25),
#  ('mtb:scale:uphill', 25),
#  ('destination', 25),
#  ('recycling:glass_bottles', 25),
#  ('line', 24),
#  ('shelter_type', 24),
#  ('bicycle_parking', 24),
#  ('office', 24),
#  ('by_night', 23),
#  ('ref:INSEE', 23),
#  ('postal_code', 23),
#  ('trees', 23),
#  ('recycling:plastic_packaging', 23),
#  ('alt_name', 22),
#  ('political_division', 21),
#  ('recycling:plastic_bottles', 21),
#  ('direction', 21),
#  ('railway:kvb', 20),
#  ('addr:country', 20),
#  ('information', 20),
#  ('religion', 19),
#  ('name:es', 18),
#  ('par', 18),
#  ('handicap', 18),
#  ('heritage:operator', 18),
#  ('heritage', 18),
#  ('dispensing', 18),
#  ('noexit', 18),
#  ('name:it', 17),
#  ('source:heritage', 17),
#  ('ref:mhs', 17),
#  ('mhs:inscription_date', 17),
#  ('restriction', 16),
#  ('reservation', 16),
#  ('intermittent', 16),
#  ('recycling:cartons', 16),
#  ('motorcar', 16),
#  ('traffic_sign', 16),
#  ('name:cat', 15),
#  ('via', 15),
#  ('dining', 15),
#  ('segregated', 15),
#  ('ref:FR:RTE', 15),
#  ('water', 15),
#  ('lit', 15),
#  ('atm', 15),
#  ('substance', 14),
#  ('recycling:glass', 14),
#  ('ref:FR:prix-carburants', 14),
#  ('fuel:diesel', 14),
#  ('supervised', 13),
#  ('noname', 13),
#  ('fuel:octane_98', 13),
#  ('source:postal_code', 12),
#  ('source:population', 12),
#  ('population', 12),
#  ('fire_hydrant:type', 12),
#  ('denomination', 12),
#  ('healthcare', 12),
#  ('ref:FR:SIRET', 12),
#  ('email', 12),
#  ('operator:type', 12),
#  ('basin', 11),
#  ('maxheight', 11),
#  ('outdoor_seating', 11),
#  ('entrance', 11),
#  ('recycling:clothes', 11),
#  ('depth', 10),
#  ('social_facility', 10),
#  ('advertising', 10),
#  ('official_name', 10),
#  ('vending_machine', 10),
#  ('vending', 10),
#  ('fuel:e10', 10),
#  ('trail_visibility', 9),
#  ('type:FR:FINESS', 9),
#  ('switch', 9),
#  ('leaf_cycle', 9),
#  ('social_facility:for', 9),
#  ('motorcycle', 9),
#  ('ref:FR:SIREN', 9),
#  ('name:en', 9),
#  ('source:name', 8),
#  ('fax', 8),
#  ('capacity:disabled', 8),
#  ('contact:street', 8),
#  ('tower:type', 8),
#  ('phases', 8),
#  ('opening_hours:covid19', 8),
#  ('swing_gate:type', 8),
#  ('payment:cash:XLT-ROUE', 8),
#  ('currency:XLT', 8),
#  ('location:transition', 8),
#  ('hgv:lanes', 8),
#  ('osmc:symbol', 7),
#  ('end_date', 7),
#  ('park_ride', 7),
#  ('ref:FR:CEF', 7),
#  ('departures_board', 7),
#  ('contact:postcode', 7),
#  ('contact:housenumber', 7),
#  ('contact:city', 7),
#  ('genus', 7),
#  ('recycling:cardboard', 7),
#  ('payment:credit_cards', 7),
#  ('air_conditioning', 7),
#  ('takeaway', 7),
#  ('compressed_air', 7),
#  ('residential', 6),
#  ('incline', 6),
#  ('maxweight', 6),
#  ('railway:tvm', 6),
#  ('healthcare:speciality', 6),
#  ('toilets', 6),
#  ('generator:source', 6),
#  ('generator:method', 6),
#  ('species', 6),
#  ('payment:cash', 6),
#  ('waste_basket', 6),
#  ('ref:FR:LaPoste', 6),
#  ('organic', 6),
#  ('drive_through', 6),
#  ('operator:wikidata', 6),
#  ('source:url', 5),
#  ('circuits', 5),
#  ('fuel:octane_95', 5),
#  ('addr:housename', 5),
#  ('class:bicycle', 5),
#  ('ref:fgkz', 5),
#  ('old_name', 5),
#  ('fuel:lpg', 5),
#  ('transformer', 5),
#  ('voltage:secondary', 5),
#  ('stars', 5),
#  ('train', 5),
#  ('recycling:plastic', 5),
#  ('contact:facebook', 5),
#  ('stamping_machine', 5),
#  ('address', 5),
#  ('disused:political_division', 4),
#  ('disused:boundary', 4),
#  ('name:bg', 4),
#  ('fence_type', 4),
#  ('sidewalk', 4),
#  ('industrial', 4),
#  ('substation', 4),
#  ('ref:FR:RTE_nom', 4),
#  ('length', 4),
#  ('waste', 4),
#  ('generator:output:electricity', 4),
#  ('bulk_purchase', 4),
#  ('fire_hydrant:position', 4),
#  ('toilets:wheelchair', 4),
#  ('drinking_water', 4),
#  ('source_id', 4),
#  ('payment:visa', 4),
#  ('payment:mastercard', 4),
#  ('copy_facility', 4),
#  ('police:FR', 4),
#  ('enforcement', 4),
#  ('osmc:ref', 3),
#  ('protection_title', 3),
#  ('protect_class', 3),
#  ('ref:sandre', 3),
#  ('disused:local_authority:FR', 3),
#  ('bridge:structure', 3),
#  ('disabled', 3),
#  ('generator:type', 3),
#  ('internet_access', 3),
#  ('boules', 3),
#  ('sac_scale', 3),
#  ('date', 3),
#  ('observatory:type', 3),
#  ('psv', 3),
#  ('crop', 3),
#  ('maxspeed:type', 3),
#  ('diameter', 3),
#  ('ford', 3),
#  ('valve', 3),
#  ('pipeline', 3),
#  ('light_source', 3),
#  ('mapillary', 3),
#  ('indoor', 3),
#  ('artwork_type', 3),
#  ('unisex', 3),
#  ('toilets:disposal', 3),
#  ('image', 3),
#  ('smoking', 3),
#  ('level', 3),
#  ('recycling:waste', 3),
#  ('craft', 3),
#  ('contact:fax', 3),
#  ('contact:twitter', 3),
#  ('line_attachment', 3),
#  ('ref:FR:GendarmerieNationale', 3),
#  ('exit_to', 3),
#  ('network:type', 2),
#  ('roundtrip', 2),
#  ('distance', 2),
#  ('collection', 2),
#  ('ref:FR:INPN', 2),
#  ('name:lt', 2),
#  ('roof:colour', 2),
#  ('lanes:forward', 2),
#  ('genus:fr', 2),
#  ('ref:FR:SINOE', 2),
#  ('recycling:scrap_metal', 2),
#  ('recycling:green_waste', 2),
#  ('operator:wikipedia', 2),
#  ('uic_ref', 2),
#  ('health_facility:type', 2),
#  ('military', 2),
#  ('FIXME', 2),
#  ('name:etymology:wikidata', 2),
#  ('lanes:bus', 2),
#  ('maxstay', 2),
#  ('parking:lane:left', 2),
#  ('parking:lane:right', 2),
#  ('oneway:bicycle', 2),
#  ('maxspeed:lanes', 2),
#  ('facebook', 2),
#  ('is_in', 2),
#  ('fuel:e85', 2),
#  ('crossing:island', 2),
#  ('recycling:newspaper', 2),
#  ('recycling:magazines', 2),
#  ('kerb', 2),
#  ('government', 2),
#  ('water_tank:volume', 2),
#  ('beacon:type', 2),
#  ('beacon:frequency', 2),
#  ('airmark', 2),
#  ('contact:website', 2),
#  ('inscription', 2),
#  ('drink:wine', 2),
#  ('delivery', 2),
#  ('recycling:electrical_appliances', 2),
#  ('payment:debit_cards', 2),
#  ('voltage:primary', 2),
#  ('utility', 2),
#  ('telecom:medium', 2),
#  ('telecom', 2),
#  ('owner', 2),
#  ('tower', 2),
#  ('local_ref', 2),
#  ('ref:FR:CNC', 2),
#  ('name:ca', 2),
#  ('symbol', 1),
#  ('to:fr', 1),
#  ('pilgrimage', 1),
#  ('name:zh', 1),
#  ('name:uk', 1),
#  ('name:tr', 1),
#  ('name:sv', 1),
#  ('name:sr-Latn', 1),
#  ('name:sr', 1),
#  ('name:sl', 1),
#  ('name:sk', 1),
#  ('name:ro', 1),
#  ('name:pt', 1),
#  ('name:pl', 1),
#  ('name:no', 1),
#  ('name:nn', 1),
#  ('name:nl', 1),
#  ('name:lb', 1),
#  ('name:ko', 1),
#  ('name:ka', 1),
#  ('name:ja', 1),
#  ('name:is', 1),
#  ('name:hu', 1),
#  ('name:hr', 1),
#  ('name:fi', 1),
#  ('name:et', 1),
#  ('name:eo', 1),
#  ('name:el', 1),
#  ('name:da', 1),
#  ('name:cv', 1),
#  ('name:cs', 1),
#  ('name:bs', 1),
#  ('name:be', 1),
#  ('name:an', 1),
#  ('int_network', 1),
#  ('region:type', 1),
#  ('ref:aveo', 1),
#  ('from:fr', 1),
#  ('designation', 1),
#  ('short_name', 1),
#  ('iucn_level', 1),
#  ('milestone', 1),
#  ('name:ar', 1),
#  ('description:fr', 1),
#  ('mtb', 1),
#  ('car_pooling', 1),
#  ('mtb:type', 1),
#  ('fitness_station', 1),
#  ('abandoned', 1),
#  ('animal_keeping:type', 1),
#  ('animal_keeping', 1),
#  ('ref:EU:ENTSOE_EIC', 1),
#  ('plant:source', 1),
#  ('plant:output:electricity', 1),
#  ('plant:method', 1),
#  ('destination:forward', 1),
#  ('dog', 1),
#  ('turn:lanes', 1),
#  ('path', 1),
#  ('disabled_spaces', 1),
#  ('content', 1),
#  ('building:roof:shape', 1),
#  ('road_marking', 1),
#  ('turn:lanes:backward', 1),
#  ('lanes:backward', 1),
#  ('recycling:small_appliances', 1),
#  ('recycling:batteries', 1),
#  ('construction', 1),
#  ('internet_access:fee', 1),
#  ('parking:name', 1),
#  ('roof:material', 1),
#  ('recycling:white_goods', 1),
#  ('recycling:wasted_oil', 1),
#  ('recycling:tyres', 1),
#  ('recycling:hazardous_waste', 1),
#  ('recycling:computers', 1),
#  ('min_age', 1),
#  ('max_age', 1),
#  ('kindergarten:FR', 1),
#  ('step_count', 1),
#  ('boat', 1),
#  ('water_point', 1),
#  ('sanitary_dump_station', 1),
#  ('wires', 1),
#  ('class:racebike', 1),
#  ('tower:construction', 1),
#  ('note:railway', 1),
#  ('source:building', 1),
#  ('contact:email', 1),
#  ('source:shape', 1),
#  ('community:fr', 1),
#  ('community', 1),
#  ('wood', 1),
#  ('icao', 1),
#  ('note:fr', 1),
#  ('mtb:scale:imba', 1),
#  ('ref:FR:GeoDAE', 1),
#  ('defibrillator:location', 1),
#  ('ref:FR:Allocine', 1),
#  ('bar', 1),
#  ('recycling:shoes', 1),
#  ('artist_name', 1),
#  ('access:covid19', 1),
#  ('surveillance:zone', 1),
#  ('surveillance:type', 1),
#  ('surveillance', 1),
#  ('contact:webcam', 1),
#  ('water_source', 1),
#  ('couplings', 1),
#  ('survey:date', 1),
#  ('lottery', 1),
#  ('post_office:type', 1),
#  ('recycling:beverage_cartons', 1),
#  ('recycling:PET', 1),
#  ('stairs', 1),
#  ('species:fr', 1),
#  ('socket:type2_combo:output', 1),
#  ('socket:type2_combo', 1),
#  ('socket:type2:output', 1),
#  ('socket:type2', 1),
#  ('socket:chademo:output', 1),
#  ('socket:chademo', 1),
#  ('ref:EU:EVSE', 1),
#  ('charging_station:output', 1),
#  ('authentication:nfc', 1),
#  ('authentication:membership_card', 1),
#  ('authentication:app', 1),
#  ('amperage', 1),
#  ('communication:mobile_phone', 1),
#  ('change:XLT-ROUE', 1),
#  ('mobile', 1),
#  ('collection_times', 1),
#  ('public_bookcase:type', 1),
#  ('takeaway:covid19', 1),
#  ('summit:cross', 1),
#  ('traffic_sign:forward', 1),
#  ('side', 1),
#  ('recording:automated', 1),
#  ('recording', 1),
#  ('monitoring:meteoric_activity', 1),
#  ('display', 1),
#  ('beacon:code', 1),
#  ('beacon:channel', 1),
#  ('fire_hydrant:count', 1),
#  ('board_type', 1),
#  ('alcohol', 1),
#  ('bollard', 1),
#  ('community_centre:for', 1),
#  ('recycling:packaging', 1),
#  ('dance:teaching', 1),
#  ('beauty', 1),
#  ('wifi', 1),
#  ('deaf:description:fr', 1),
#  ('map_type', 1),
#  ('ref:RFF:ligne', 1),
#  ('level_crossing:type:RFF', 1),
#  ('line_management', 1),
#  ('traffic_signals:direction', 1),
#  ('note:cadastre', 1),
#  ('screen', 1),
#  ('cinema:3D', 1),
#  ('brand:website', 1),
#  ('name:ru', 1)]

# %% [markdown]
# ***What I will check according to result***
#
#  City names occurences and post code seems easy to check because I choose an area with less than a dozen of towns I know very well
#
#  ('addr:city', 137),
#  ('addr:postcode', 136),

# %% [markdown]
# ### Postcode analysis
#
# Now, I check the keys postcode value and count them.
#
# My goal will be to look for wrong value

# %%
#
#Basic code I'll use to go trhu the XML and count.
#
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.ElementTree as ET
import re
from pprint import pprint
import operator

#osm_file = 'data/small_sample_map.osm'
osm_file = 'data/map.osm'

def count_tags(filename):
    #count is a dictionary, dictionary manage pairs
    count = {}
    #Loop all the element in the file at first level !
    #All element are tags
    for _, element in ET.iterparse(filename):
        #print(element.tag)
        tagK = element.get('k')
        #tagK variable <= Key name
        #If there is a k value check it
        if tagK == 'addr:postcode':
            #if if it is the right one get the value
            tagV = element.get('v')
            #If value is not present in the count dict
            #add value in the dict with value 1
            if tagV not in count.keys():
                count[tagV] = 1
            #If value is already existing in the count dict
            #add 1  to the count of the already existing tag name
            else:
                count[tagV] += 1

    return count



def main():
    #call function and return a dictionary
    count = count_tags(osm_file)
    #Sort dictionary
    count = sorted(count.items(), key=operator.itemgetter(1))[::-1]
    #Display dictionary !
    pprint(count)

    
if __name__ == "__main__":
    main()
# Out:
# [('13300', 71),
#  ('13330', 34),
#  ('13680', 22),
#  ('13450', 5),
#  ('13430', 2),
#  ('13661', 1),
#  ('13121', 1)]

# %% [markdown]
# ***Postcodes have the expected format***

# %% [markdown]
# ## citynames analysis
#
# Now, I check the keys citynames value and count them.
#
# My goal will be to look for wrong value

# %%
#
#Basic code I'll use to go trhu the XML and count.
#
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.ElementTree as ET
import re
from pprint import pprint
import operator

#osm_file = 'data/small_sample_map.osm'
osm_file = 'data/map.osm'

def count_tags(filename):
    #count is a dictionary, dictionary manage pairs
    count = {}
    #Loop all the element in the file at first level !
    #All element are tags
    for _, element in ET.iterparse(filename):
        #print(element.tag)
        tagK = element.get('k')
        #tagK variable <= Key name
        #If there is a k value count it
        if tagK == 'addr:city':
            tagV = element.get('v')
            #If Key name is not present in the count dict
            #add Key name in the dict with value 1
            if tagV not in count.keys():
                count[tagV] = 1
            #If tag name is already existing in the count dict
            #add 1  to the value of the already existing tag name
            else:
                count[tagV] += 1

    return count



def main():
    #call function and return a dictionary
    count = count_tags(osm_file)
    #Sort dictionary
    count = sorted(count.items(), key=operator.itemgetter(1))[::-1]
    #Display dictionary !
    pprint(count)

    
if __name__ == "__main__":
    main()
# Out:
# [('Salon-de-Provence', 64),
#  ('Pélissanne', 46),
#  ('Lançon-Provence', 14),
#  ('Grans', 2),
#  ('Eyguières', 2),
#  ('PELISSANNE', 2),
#  ('Lançon-En-Provence', 2),
#  ('Aurons', 1),
#  ('Pelissanne', 1),
#  ('La Barben', 1),
#  ('Lançon', 1),
#  ('Salon de Provence', 1)]

# %% [markdown]
# ***Some city names are not written in the same way***
#
#
# I'll have to take care of them when I transpose the data into a database
#
# I'll make this work in another file.

# %% [markdown]
# ## Road name analysis
#
# More complicated, I'll analyze road names

# %%
#
#Basic code I'll use to go trhu the XML and count.
#
#!/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.ElementTree as ET
import re
import operator
from pprint import pprint

osm_file = 'data/small_sample_map.osm'
#osm_file = 'data/map.osm'

decoupe = re.compile(r'\W+')

def audit():
    typeOfWays = {}
    for _, element in ET.iterparse(osm_file):
        #As we want only name of road, I check for name tag in way containing tag highway
        for way in element.iter('way'):
            for tag in way.iter('tag'):
                if tag.attrib['k'] == "highway":
                    for tag in way.iter('tag'):
                        if tag.attrib['k'] == "name":
                            streetName = tag.attrib['v']
                            #print(streetName)
                            #According to regular expression I want only the first word of the full street name
                            typeOfStreetName = decoupe.split(streetName)[0]
                            #I count the type !
                            if (typeOfStreetName) not in typeOfWays.keys():
                                   typeOfWays[typeOfStreetName] = 1
                            else:
                                    #print(elem.tag)
                                    typeOfWays[typeOfStreetName] += 1
    return typeOfWays



def main():
    typeOfWays = audit()
    typeOfWays = sorted(typeOfWays.items(), key=operator.itemgetter(1))[::-1]
    pprint(typeOfWays)

    
if __name__ == "__main__":
    main()
# Out:
# [('Rue', 70),
#  ('Chemin', 52),
#  ('Avenue', 30),
#  ('Boulevard', 26),
#  ('Impasse', 22),
#  ('Allée', 20),
#  ('Allées', 14),
#  ('Rond', 12),
#  ('Ancien', 6),
#  ('Accès', 2),
#  ('Carrefour', 2)]

# %% [markdown]
# ***No problem on ways type***

# %% [markdown]
# ## For test purpose only, to be deleted

# %%
# !/usr/bin/env python
# -*- coding: utf-8 -*-
import xml.etree.ElementTree as ET
import re
from pprint import pprint
import operator

osm_file = 'data/small_sample_map.osm'
#osm_file = 'data/map.osm'

def count_tags(filename):
    count = {}
    #Loop all the element in the file at first level !
    for _, elem1 in ET.iterparse(filename):
        print(elem1.tag,"->",elem1.keys() )
        #Loop all the elements into the first level tag !
        for subtag in elem1:
            print ("-",subtag.tag , "->", subtag.keys())
            for subsubtag in subtag:
               print ("--",subsubtag.tag , "->", subsubtag.keys())
                 
                
    return count



def main():
    count = count_tags(osm_file)
    count = sorted(count.items(), key=operator.itemgetter(1))[::-1]
    pprint(count)

    
if __name__ == "__main__":
    main()
